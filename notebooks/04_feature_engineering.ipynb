# %% [markdown]
# # Feature Engineering Specification — Spotify Cross-Border Diffusion Model
#
# ---
#
# ## 1. Prediction Objective
#
# The objective of this project is to model the **cross-border diffusion of tracks across Spotify markets**.
#
# For each track and each possible target country, we predict:
#
# - **Classification task:**
#   `did_enter_target_country` → Will the track ever chart in this country?
#
# - **Regression task:**
#   `days_to_enter_target_country` → How many days after the reference point will it chart there?
#
# Each row in the training dataset represents one prediction scenario:
#
# ```
# (track_id, target_country, reference_time)
# ```
#
# This simulates making a prediction at a specific moment in time, using only information available at that time.
#
# **FRAGE @MICHAEL**: Wollen wir wirklich 1 oder 0 machen? Oder wollen wir eine Art Ranker bauen, der vorhersagt in welchen 5 Ländern als nächstes in den nächstes X Tagen?
#
# ---
#
# ## 2. Reference Time Definition
#
# ### Definition
#
# We define:
#
# ```
# reference_time = first global chart appearance of the track (Top 200 only)
# ```
#
# SQL construction:
#
# ```sql
# SELECT track_id, MIN(date) AS reference_time
# FROM spotify_data
# WHERE chart = 'top200'
# GROUP BY track_id;
# ```
#
# ### Why this reference time is chosen
#
# At this moment, the following information is **known**:
# - Track intrinsic properties
# - Artist historical performance
# - Market characteristics
# - Origin country (first chart appearance) -> **FRAGE: Was ist wenn Song in mehren countries gleichzeitig chartet**
#
# At this moment, the following information is **NOT yet known**:
# - Whether the track will enter other countries later
# - When it will enter other countries
#
# This ensures that the model does not use future information and prevents temporal leakage.
#
# ---
#
# ## 3. Feature Categories Overview
#
# We engineer features in the following logical groups:
#
# | Category | Purpose |
# |----------|---------|
# | Identifiers and targets | Define training dataset structure |
# | Track intrinsic features | Describe inherent properties of the track |
# | Artist features | Capture artist strength and global reach |
# | Diffusion state features | Capture how far the track has already spread |
# | Target country features | Describe structural properties of the destination market |
# | Geographic relationship features | Describe relationship between origin and target country |
# | Temporal features | Capture seasonal timing effects |
#
# Together, these model:
#
# ```
# track attractiveness × artist strength × current diffusion state × market receptiveness × geographic proximity
# ```
#
# ---
#
# ## 4. Feature Definitions and Construction
#
# ---
#
# ### Category A — Identifiers and Targets
#
# These define dataset structure and prediction labels.
# **IST DIE IDEE, DASS WIR FÜR JEDEN SONG EINZELN FÜR JEDES LAND PREDICTED ODER SOLL UNSER ENDOUTPUT SEIN, HEY DIESER SONG KOMMT DANACH IN DEN 5 LÄNDERN**
#
# | Feature | Description | Source Columns | How to Build |
# |---------|-------------|----------------|--------------|
# | `track_id` **MACHT DAS SINN?**   | Track identifier | `track_id` | Direct column |
# | `target_country` | Country to predict entry into | `region` | Cross join tracks with all countries |
# | `reference_time` | First global chart date (Top 200) | `date`, `chart` | `MIN(date) WHERE chart = 'top200' GROUP BY track_id` |
# | `origin_country` | First charting country | `region`, `date` | `region WHERE date = reference_time` |
# | `did_enter_target_country` | Classification target | `region`, `date` | `1` if track appears in `target_country` Top 200 at `date > reference_time` |
# | `days_to_enter_target_country` | Regression target | `region`, `date` | `MIN(date_target_country) − reference_time` |
#
# ---
#
# ### Category B — Track Intrinsic Features
#
# These features describe inherent properties of the track and are known immediately.
#
# | Feature | Description | Source Columns | How to Build |
# |---------|-------------|----------------|--------------|
# | `song_language` | Language of the song | `artist`, `origin_country` | Inferred from artist metadata and origin country |
# | `days_since_release` | Track age at prediction time | `release_date`, `date` | `reference_time − release_date` |
# | `available_markets_count` | Number of markets track is available in | `available_markets` | Count number of markets in `available_markets` |
# | `duration_ms` | Track length | `duration_ms` | `TRY_CAST(duration_ms AS DOUBLE)` |
# | `explicit_flag` | Explicit content indicator | `explicit` | Convert to binary (1 if true, else 0) |
# | `release_day_of_week` | Day of week the song was released | `release_date` | `EXTRACT(DOW FROM release_date)` |
#
# Audio features (intrinsic track properties):
#
# | Feature | Source | How to Build |
# |---------|--------|--------------|
# | `af_danceability` | `af_danceability` | Value `WHERE date = reference_time` |
# | `af_energy` | `af_energy` | Same |
# | `af_valence` | `af_valence` | Same |
# | `af_tempo` | `af_tempo` | Same |
# | `af_loudness` | `af_loudness` | Same |
# | `af_acousticness` | `af_acousticness` | Same |
# | `af_speechiness` | `af_speechiness` | Same |
# | `af_instrumentalness` | `af_instrumentalness` | Same |
# | `af_liveness` | `af_liveness` | Same |
#
# > **Note:** `popularity_at_reference_time` was excluded. Spotify's popularity score is algorithmically updated based on recent streams and could act as a leaky proxy for the target variable.
#
# ---
#
# ### Category C — Artist-Level Features
#
# These describe artist historical success and global reach.
#
# **Computed using only observations BEFORE `reference_time`.**
#
# | Feature | Description | Source Columns | How to Build |
# |---------|-------------|----------------|--------------|
# | `artist_prior_chart_count` | Total prior chart entries | `artist`, `date` | `COUNT(*) WHERE date < reference_time` |
# | `artist_prior_unique_regions` | Number of countries artist charted in | `artist`, `region`, `date` | `COUNT(DISTINCT region) WHERE date < reference_time` |
# | `artist_prior_best_rank` | Best rank achieved historically | `rank`, `artist`, `date` | `MIN(rank) WHERE date < reference_time` |
# | `artist_prior_unique_tracks` | Number of tracks charted | `track_id`, `artist`, `date` | `COUNT(DISTINCT track_id) WHERE date < reference_time` |
# | `multi_artist_flag` | Collaboration indicator | `artist` | `1` if artist contains "feat.", "&", or "," |
#
# ---
#
# ### Category D — Diffusion State Features
#
# These capture the track's initial charting strength at `reference_time`.
#
# | Feature | Description | Source Columns | How to Build |
# |---------|-------------|----------------|--------------|
# | `num_regions_entered_so_far` | Countries already entered | `region`, `date` | `COUNT(DISTINCT region) WHERE date ≤ reference_time` |
# | `num_continents_entered_so_far` | Continents entered | `country_continent` | `COUNT(DISTINCT country_continent) WHERE date ≤ reference_time` |
# | `origin_is_major_market` | Origin country is US, UK, or DE | `origin_country` | `1` if origin in ('US', 'UK', 'DE') |
# | `best_rank_so_far` | Best chart position on debut | `rank`, `date` | `MIN(rank) WHERE date ≤ reference_time` |
# | `streams_sum_so_far` | Total streams on debut | `streams`, `date` | `SUM(streams) WHERE date ≤ reference_time` |
# | `is_viral50_flag` | Track is on the Viral 50 chart at reference time | `chart`, `date` | `1` if track appears in `chart = 'viral50'` at `date ≤ reference_time` |
# | `same_language_country_entered_count` | Countries with same language already entered | `country_official_language` | `COUNT WHERE language matches origin_country` |
#
# > **Note:** At `reference_time` (first chart day), many diffusion features will have limited variation (e.g., `num_regions_entered_so_far` often = 1). They still capture debut strength. The `is_viral50_flag` adds a distinct signal — organic buzz vs. raw streaming volume.
#
# > **Note:** `streams_sum_so_far` is borderline — first-day streams may partially reflect which markets are already engaged. Keep but flag in the report and test the model with and without it.
#
# ---
#
# ### Category E — Target Country Features
#
# These describe structural properties of the destination market.
#
# | Feature | Description | Source Columns | How to Build |
# |---------|-------------|----------------|--------------|
# | `target_country_population` | Market size proxy | `country_population` | Join on `target_country` |
# | `target_country_continent` | Geographic region | `country_continent` | Join |
# | `target_country_language` | Official language(s) | `country_official_language` | Join |
# | `target_country_chart_turnover_rate` | Market volatility | `trend`, `region` | Fraction of NEW_ENTRY rows in trailing window |
# | `target_country_total_streams_recent` | Market activity level | `streams`, `region` | `SUM(streams)` in trailing window |
#
# ---
#
# ### Category F — Geographic & Cultural Relationship Features
#
# These capture proximity between the song's origin and the target country.
#
# | Feature | Description | Source Columns | How to Build |
# |---------|-------------|----------------|--------------|
# | `same_language_flag` | Song language matches target country language | `song_language`, `country_official_language` | Compare song language and target language |
# | `same_continent_flag` | Shared continent | `country_continent` | Compare origin and target continent |
# | `artist_prior_success_in_target_country` | Has this artist charted in this specific target country before? | `artist`, `region`, `date` | `COUNT(DISTINCT track_id) WHERE region = target_country AND date < reference_time` |
# | `neighbor_country_entered_flag` | Neighbor diffusion signal | `cultural_top5_targets` | Check if culturally close country already entered |
# | `cultural_distance_origin_target` | Cultural distance measure | cultural distance table | Join origin and target country |
#
# ---
#
# ### Category G — Temporal Features
#
# These capture seasonal timing effects.
#
# | Feature | Description | Source Columns | How to Build |
# |---------|-------------|----------------|--------------|
# | `reference_month` | Month of reference_time | `reference_time` | `EXTRACT(MONTH FROM reference_time)` |
# | `reference_day_of_week` | Day of week of first chart appearance | `reference_time` | `EXTRACT(DOW FROM reference_time)` |
#
# ---
#
# ## 5. Leakage Prevention Rules
#
# Strict rules must be followed:
#
# - Only use data where `date ≤ reference_time`
# - Never use `target_country` rank before entry
# - Never use `target_country` streams before entry
# - Never use Spotify `popularity` score (algorithmically updated, reflects current performance)
# - Never use any future information
#
# This ensures realistic prediction conditions.
#
# ---
#
# ## 6. Final Training Dataset Structure
#
# Each row contains:
#
# ```
# track_id
# target_country
# reference_time
# origin_country
#
# [all engineered features from Categories B–G]
#
# did_enter_target_country          ← classification target
# days_to_enter_target_country      ← regression target
# ```
#
# Estimated dataset size:
#
# ~10,000–20,000 unique tracks × 35 countries ≈ ~350,000–700,000 rows
#
# DuckDB will be used to construct and query this dataset efficiently.

# %% [markdown]
# # Top-5 Country Ranker — Architecture (EDA-Informed)
#
# ---
#
# ## Overview: What We're Building
#
# **Input:** Everything known about a song at a given point in time — it may already be charting in 1, 3, or 10 countries.
#
# **Output:** The 5 most likely countries the song will chart in **next**, each with a predicted number of days until entry (within a 30-day horizon).
#
# ```
# ┌─────────────────────────────────────────────────────────────────────┐
# │  OBSERVATION POINT (reference_time)                                 │
# │                                                                     │
# │  Song is already in countries {X, Y, Z}                             │
# │  Known: audio features, artist history, current diffusion state,    │
# │         market properties, cultural distances                       │
# └──────────────────────────┬──────────────────────────────────────────┘
#                            │
#                            ▼
#           ┌────────────────────────────────┐
#           │  For each REMAINING candidate  │
#           │  country: Score (song, country)│
#           └───────────┬────────────────────┘
#                       │
#            ┌──────────┴──────────┐
#            ▼                     ▼
#    ┌──────────────┐    ┌──────────────────┐
#    │   MODEL 1    │    │    MODEL 2       │
#    │  Classifier  │    │   Regressor      │
#    │              │    │                  │
#    │  P(charts    │    │  E[days to       │
#    │  within 30d) │    │  entry | entry]  │
#    └──────┬───────┘    └────────┬─────────┘
#           │                     │
#           ▼                     ▼
#    ┌─────────────────────────────────────┐
#    │  RANKING LAYER                      │
#    │  Sort remaining countries by P      │
#    │  Return top 5 + predicted days      │
#    └─────────────────────────────────────┘
#
# Output example (song already in Brazil, Portugal, Argentina):
#   1. Spain       — P=0.81, predicted entry in ~2 days
#   2. Germany     — P=0.72, predicted entry in ~5 days
#   3. France      — P=0.68, predicted entry in ~8 days
#   4. Italy       — P=0.55, predicted entry in ~12 days
#   5. Colombia    — P=0.49, predicted entry in ~18 days
# ```
#
# ### Key Design Decision: Flexible Observation Point
#
# The model does NOT only predict at day 1. It can be applied at **any point** in a song's lifetime:
#
# - **Day 1:** Song just appeared in Brazil → predict next 5 countries
# - **Day 5:** Song now in Brazil + Portugal + Argentina → predict next 5 from remaining countries
# - **Day 14:** Song in 8 countries → predict next 5 from the ~57 remaining
#
# This is powerful because the **diffusion state features change** with each observation point — the model gets richer input as the song spreads. In training, we can generate multiple rows per track at different observation points.
#
# ### Is This an ML Model?
#
# Yes. This is a **pointwise learning-to-rank** system built from two standard ML models:
#
# 1. **Model 1 — Binary classifier** (e.g., Logistic Regression, Ridge Classifier, or Gradient Boosted Trees)
#    - Trained on all (song, candidate_country, observation_time) triples
#    - Predicts `P(song charts in country within 30 days of observation_time)`
#    - This probability becomes the **ranking score**
#
# 2. **Model 2 — Regression model** (e.g., Ridge Regression, Lasso, or Gradient Boosted Regressor)
#    - Trained only on **positive pairs** (songs that actually entered the country within 30 days)
#    - Predicts `days_to_entry` (continuous, range 1–30)
#    - Provides the **timeline** for the top-5 output
#
# Both models use the same feature set (Categories B–G). The "ranker" is just sorting by Model 1's output — no separate ranking model needed.
#
# This fits within the course scope (logistic regression, Ridge, Lasso) while also allowing more advanced models later.

# %% [markdown]
# ## Prediction Targets (Revised for Top-5 Ranker)
#
# ### Target 1 — Classification: `did_enter_within_30d`
#
# ```
# 1 if the track charts in target_country within 30 days of reference_time
# 0 otherwise
# ```
#
# **30-day horizon rationale (from EDA):**
# - 44.3% of all cross-border arrivals happen within the first 7 days
# - 64.4% happen within the first 30 days
# - 30 days captures the majority of genuine diffusion events
# - Beyond 30 days, arrivals become increasingly noisy (catalog rediscovery, playlist adds, etc.)
#
# ### Target 2 — Regression: `days_to_entry`
#
# ```
# Number of days from reference_time to first chart appearance in target_country
# Range: 1–30 (only trained on positive examples)
# ```
#
# No log-transform needed here — the 1–30 range is compact enough for linear models.
#
# ### Class Imbalance (Critical — from EDA)
#
# The EDA found that **73.1% of songs never leave their first country**. With a 30-day window:
#
# - Estimated positive rate per (song, country) pair: **~3–7%**
# - For ~118K tracks × ~60 candidate countries = ~7M potential pairs, only a small fraction are positive
#
# **Handling strategies:**
# 1. **Class weights** in the classifier (`class_weight='balanced'` in sklearn)
# 2. **Downsample negatives** to ~3:1 or 5:1 ratio during training
# 3. **Evaluation metric**: Use **NDCG@5** and **Precision@5** (not accuracy) — we care about the top of the ranking, not overall classification
# 4. **Stratified sampling** by track to prevent data leakage from the same track appearing in train and test

# %% [markdown]
# ## Reference Time & Observation Points (Revised)
#
# ### Flexible Observation Points — Not Just Day 1
#
# The original spec defined `reference_time` as the first chart appearance. The revised design supports **any observation point** during a song's chart life:
#
# ```
# observation_time = any date where the track is on at least one chart
# ```
#
# This means the model can be queried at day 1, day 5, day 7, day 20 — whenever a record label wants to know "where will this song go next?"
#
# ### How Training Rows Are Generated
#
# For each track, we sample **multiple observation points** to create training data:
#
# ```
# Track "X" chart timeline:
#   Day 0:  enters Brazil
#   Day 3:  enters Argentina
#   Day 5:  enters Portugal
#   Day 12: enters Spain
#   Day 25: enters France
#
# Training rows generated (observation at day 0):
#   (X, day_0, Argentina, entered=1, days=3)     -- candidate: Argentina
#   (X, day_0, Portugal,  entered=1, days=5)     -- candidate: Portugal
#   (X, day_0, Spain,     entered=1, days=12)    -- candidate: Spain
#   (X, day_0, France,    entered=1, days=25)    -- candidate: France
#   (X, day_0, Germany,   entered=0, days=NULL)  -- candidate: Germany (never entered in 30d)
#   (X, day_0, Japan,     entered=0, days=NULL)  -- candidate: Japan (never entered in 30d)
#   ... (one row per remaining candidate country)
#
# Training rows generated (observation at day 5):
#   (X, day_5, Spain,     entered=1, days=7)     -- 12-5=7 days from this observation
#   (X, day_5, France,    entered=1, days=20)    -- 25-5=20 days
#   (X, day_5, Germany,   entered=0, days=NULL)  -- still didn't enter
#   ... (candidates = all countries MINUS {Brazil, Argentina, Portugal})
# ```
#
# **Key insight:** The same track produces different training rows at different observation points because:
# - The **candidate set shrinks** (countries already entered are excluded)
# - The **diffusion state features change** (more countries entered, more streams accumulated)
# - The **days_to_entry changes** (relative to current observation point)
# - The **target country market state** is different (different trailing window)
#
# ### Sampling Strategy for Observation Points
#
# Generating a row at *every* day of a track's life would be too many rows. Instead, sample strategically:
#
# | Observation Point | Why Include It |
# |---|---|
# | **Day of first chart entry** | Captures the "cold start" prediction scenario |
# | **Day a new country is entered** | Captures the moment diffusion state changes — model sees the track right after growth |
# | **Random sample of other days** | Fills gaps, ensures the model sees "quiet" days too (no new country entered) |
#
# This produces ~3–8 observation points per track instead of potentially hundreds.
#
# ### Origin Country — No Single Origin
#
# With the flexible observation model, there is no single "origin country" anymore. Instead we use:
#
# - `countries_entered_so_far` — the set of countries already charted (input to diffusion features)
# - `first_chart_country` — the country with the **best rank on the track's first chart day** (for relationship features)
#
# **On the Argentina/Australia artifact:** The previous spec's SQL used `ORDER BY rank, region` for tie-breaking, which **would favor Argentina/Australia alphabetically** when ranks are tied. Combined with timezone effects (these countries get chart updates earlier in the day), this created a double bias. The fix: we no longer rely on a single origin country for prediction. The `first_chart_country` is used only for relationship features (language/continent matching), and we use `best_rank_so_far` across ALL entered countries rather than just the origin.
#
# ### Candidate Countries for Prediction
#
# For each (track, observation_time), the candidate set is:
#
# ```
# all countries in dataset v2 (complete countries only — see below)
# MINUS countries where the track has already charted by observation_time
# ```
#
# No need to filter for active data windows anymore — dataset v2 handles that.

# %% [markdown]
# ## Revised & Extended Feature Definitions (EDA-Informed)
#
# The original Categories B–G remain valid. Below we document **additions, modifications, and EDA-driven corrections** to each category. All features now reference `observation_time` instead of `reference_time` to support flexible observation points.
#
# ---
#
# ### Category B+ — Track Intrinsic Features (Additions)
#
# | Feature | Description | EDA Rationale | How to Build |
# |---------|-------------|---------------|--------------|
# | `af_speechiness_binary` | 1 if speechiness > median | EDA: heavily right-skewed, most values near 0. Raw value adds noise. | `1 IF af_speechiness > 0.05 ELSE 0` |
# | `af_instrumentalness_binary` | 1 if instrumentalness > 0.01 | Same — near-zero distribution with long tail | `1 IF af_instrumentalness > 0.01 ELSE 0` |
# | `energy_acousticness_ratio` | energy / (acousticness + 0.01) | EDA: energy-loudness-acousticness are highly correlated. This composite captures the "electronic vs acoustic" axis without multicollinearity. | `TRY_CAST(af_energy AS DOUBLE) / (TRY_CAST(af_acousticness AS DOUBLE) + 0.01)` |
#
# **Modification — drop `af_loudness`:** EDA shows strong correlation with `af_energy` (multicollinearity). Keep `af_energy`, drop `af_loudness` to reduce redundancy. If regularization handles it, keep both but flag in report.
#
# **Modification — `song_language`:** This is hard to infer reliably from artist/country. Consider dropping or replacing with `first_chart_country_language` (the official language of the first chart country) as a proxy. More feasible and still captures language-market affinity.
#
# ---
#
# ### Category C+ — Artist Features (Additions)
#
# All artist features use `date < observation_time` to prevent leakage.
#
# | Feature | Description | EDA Rationale | How to Build |
# |---------|-------------|---------------|--------------|
# | `artist_country_ratio` | `unique_countries / unique_tracks` | EDA: Jul has 257 songs in 5 countries (local), Ed Sheeran has 123 songs in 68 countries (global). This ratio distinguishes local stars from global artists. | `artist_prior_unique_regions / GREATEST(artist_prior_unique_tracks, 1)` |
# | `artist_avg_track_reach` | Mean number of countries per prior track | Same rationale, different angle | `SUM(countries_per_track) / COUNT(tracks) WHERE date < observation_time` |
# | `artist_prior_success_in_target` | Number of prior tracks by this artist that charted in the specific target country | Directly predicts market affinity | `COUNT(DISTINCT track_id) WHERE region = target_country AND artist = X AND date < observation_time` |
#
# > **Note:** `artist_prior_success_in_target` was in Category F before. Moving it here because it's fundamentally an artist feature computed per-target. This is likely one of the **strongest features** — an artist with 10 prior hits in Germany is very likely to chart there again.
#
# ---
#
# ### Category D+ — Diffusion State Features (Revised for Flexible Observation)
#
# These are now **dynamic** — they change with each observation point, which is the main advantage of the flexible observation model. They replace the original static Category D features.
#
# | Feature | Description | EDA Rationale | How to Build |
# |---------|-------------|---------------|--------------|
# | `days_since_first_chart` | Days between first chart and observation_time | Captures song age on charts. Songs spreading after 20 days behave differently from day-1 predictions. | `DATEDIFF('day', first_chart_date, observation_time)` |
# | `num_countries_entered_so_far` | Countries entered by observation_time | Core diffusion signal. At day 0 this might be 1, at day 7 it might be 5. | `COUNT(DISTINCT region) WHERE date <= observation_time` |
# | `num_continents_entered_so_far` | Continents covered by observation_time | Cross-continental spread = global hit. | `COUNT(DISTINCT continent) WHERE date <= observation_time` |
# | `countries_entered_last_7d` | New countries entered in last 7 days | **Spread velocity** — a song that gained 4 countries this week is accelerating. EDA: 44% of spread happens in first 7 days. | `COUNT(DISTINCT region entered in [obs_time - 7, obs_time])` minus count at `obs_time - 7` |
# | `best_rank_so_far` | Best rank in ANY country by observation_time | At day 0 this is the debut rank; by day 7 the song may have climbed. | `MIN(TRY_CAST(rank AS INT)) WHERE date <= observation_time` |
# | `rank_percentile_best` | best_rank / 200 | EDA: stream volumes differ 235x. Rank percentile normalizes across markets. | `best_rank_so_far / 200.0` |
# | `streams_log_sum_so_far` | log(total streams across all entered countries + 1) | EDA: streams are log-normal, US/Brazil dominate raw values. | `LOG(SUM(TRY_CAST(streams AS DOUBLE)) + 1) WHERE date <= observation_time` |
# | `is_viral50_so_far` | Appeared on Viral 50 in any country by observation_time | EDA: viral50 = organic buzz signal, no stream count. | `1 IF EXISTS(chart = 'viral50' AND date <= observation_time)` |
# | `same_language_countries_entered` | Entered countries sharing language with target | If the song is already in 3 Spanish-speaking countries, Spain is more likely next. | `COUNT WHERE language matches AND date <= observation_time` |
#
# **Replaces:** `origin_is_major_market` (replaced by continuous features), `streams_sum_so_far` (replaced by log version), static `debut_country_count` / `debut_continent_count` (subsumed by the dynamic counts).
#
# ---
#
# ### Category E+ — Target Country Features (Additions)
#
# All trailing windows are computed relative to `observation_time`.
#
# | Feature | Description | EDA Rationale | How to Build |
# |---------|-------------|---------------|--------------|
# | `target_country_avg_daily_streams` | Mean daily streams per chart entry | EDA: US ~390K vs Luxembourg ~1.6K. This captures market size better than population alone. | `AVG(TRY_CAST(streams AS DOUBLE)) WHERE region = target AND date < observation_time AND chart = 'top200'` |
# | `target_country_unique_artists_30d` | Distinct artists charting in trailing 30 days | Markets with more diverse artist pools may be more open to new entries | `COUNT(DISTINCT artist) WHERE region = target AND date BETWEEN observation_time - 30 AND observation_time` |
# | `target_country_new_entry_rate_30d` | Fraction of chart entries in last 30 days that were NEW_ENTRY | Directly measures how receptive a market is to new songs right now | `COUNT(trend = 'NEW_ENTRY') / COUNT(*) WHERE region = target AND date BETWEEN observation_time - 30 AND observation_time` |
#
# **Modification — `target_country_total_streams_recent`:** Use `LOG(total_streams_recent + 1)` instead of raw value. The 235x magnitude difference across markets would dominate the feature space otherwise.
#
# **Modification — `target_country_language`:** One-hot encode the top 5-8 languages (English, Spanish, Portuguese, German, French, Japanese, Korean, other). Don't one-hot all languages — too sparse.
#
# **Dropped — `target_country_active_days`:** No longer needed because dataset v2 removes incomplete countries.
#
# ---
#
# ### Category F+ — Geographic & Cultural Relationship Features (Additions)
#
# | Feature | Description | EDA Rationale | How to Build |
# |---------|-------------|---------------|--------------|
# | `cultural_distance_imputed` | Cultural distance with imputation for missing values | EDA: 19.4% of rows have missing cultural distance (countries not in Hofstede). Impute with continent-pair median. | See imputation strategy below |
# | `cultural_distance_missing_flag` | 1 if cultural distance was imputed | Missing-not-at-random — the missingness itself is informative (non-Western countries) | `1 IF original cultural_distance IS NULL` |
# | `neighbor_already_entered_count` | Number of target's culturally top-5 neighbors already charted by the track | Stronger than binary flag — "3 of 5 neighbors entered" is more signal than "at least 1" | `COUNT WHERE region IN target_cultural_top5 AND date <= observation_time` |
# | `entered_same_continent_count` | Of countries entered so far, how many share continent with target | Captures regional clustering of spread | `COUNT WHERE entered_country_continent = target_continent` |
#
# **Cultural distance imputation strategy:**
# ```sql
# -- Step 1: Compute continent-pair medians from known distances
# -- Step 2: For missing pairs, use the median of (first_chart_continent, target_continent)
# -- Step 3: If continent pair also has no data, use global median
# -- Step 4: Set cultural_distance_missing_flag = 1 for all imputed rows
# ```
#
# ---
#
# ### Category G+ — Temporal Features (Additions)
#
# | Feature | Description | EDA Rationale | How to Build |
# |---------|-------------|---------------|--------------|
# | `observation_year` | Year of observation_time | EDA: YoY streaming growth (+11.5% → +0.6%). Platform maturity affects diffusion patterns. | `EXTRACT(YEAR FROM observation_time)` |
# | `observation_quarter` | Quarter (1-4) | Coarser than month, avoids 12-level categorical | `EXTRACT(QUARTER FROM observation_time)` |
# | `is_december` | December observation flag | Holiday season has different chart dynamics (Christmas songs, year-end lists) | `1 IF EXTRACT(MONTH FROM observation_time) = 12` |
# | `is_friday_release` | Released on a Friday | Industry standard "New Music Friday" — most major releases happen on Fridays | `1 IF EXTRACT(DOW FROM release_date) = 5` |

# %% [markdown]
# ## Training Dataset Structure (Top-5 Ranker)
#
# ### Row Definition
#
# Each row represents one **prediction scenario**:
#
# ```
# (track_id, observation_time, target_country)
# ```
#
# meaning: "At this point in time, given everything we know about this track's spread so far, will it chart in this target country within 30 days?"
#
# ### On `track_id` — Identifier, NOT a Feature
#
# `track_id` is **never fed into the model**. It is kept in the dataset only for:
# - **Joining** predictions back to song metadata for evaluation and display
# - **Ensuring correct temporal split** — all observation points of the same track must be in the same split
# - **Debugging** — tracing wrong predictions back to specific songs
#
# It is dropped before the feature matrix enters the model. Same for `observation_time` and `target_country` (as raw strings) — they define the row but are not features. The model only sees the engineered numeric/categorical features.
#
# ### Full Schema
#
# ```
# ── IDENTIFIERS (dropped before training) ────────────────────────
# track_id                          VARCHAR    -- for joins and debugging only
# observation_time                  DATE       -- when this prediction is being made
# target_country                    VARCHAR    -- country we're predicting for
# first_chart_country               VARCHAR    -- best-ranked country on first chart day
#
# ── TARGETS ──────────────────────────────────────────────────────
# did_enter_within_30d              INT        -- 0 or 1 (classification target)
# days_to_entry                     INT        -- 1–30 or NULL (regression target, only for positives)
#
# ── CATEGORY B: TRACK INTRINSIC ──────────────────────────────────
# days_since_release                INT        -- observation_time − release_date
# available_markets_count           INT        -- number of available markets
# duration_ms                       DOUBLE     -- track length
# explicit_flag                     INT        -- 0 or 1
# release_day_of_week               INT        -- 0–6
# is_friday_release                 INT        -- 0 or 1
# af_danceability                   DOUBLE     -- audio feature
# af_energy                         DOUBLE     -- audio feature
# af_valence                        DOUBLE     -- audio feature
# af_tempo                          DOUBLE     -- audio feature
# af_acousticness                   DOUBLE     -- audio feature
# af_speechiness                    DOUBLE     -- audio feature (keep raw + binary)
# af_instrumentalness               DOUBLE     -- audio feature (keep raw + binary)
# af_liveness                       DOUBLE     -- audio feature
# af_speechiness_binary             INT        -- 0 or 1
# af_instrumentalness_binary        INT        -- 0 or 1
# energy_acousticness_ratio         DOUBLE     -- composite feature
#
# ── CATEGORY C: ARTIST ───────────────────────────────────────────
# artist_prior_chart_count          INT        -- total prior chart appearances
# artist_prior_unique_regions       INT        -- countries artist has charted in
# artist_prior_best_rank            INT        -- best rank ever (lower = better)
# artist_prior_unique_tracks        INT        -- distinct prior tracks on charts
# multi_artist_flag                 INT        -- 0 or 1 (collaboration)
# artist_country_ratio              DOUBLE     -- unique_regions / unique_tracks
# artist_avg_track_reach            DOUBLE     -- mean countries per prior track
# artist_prior_success_in_target    INT        -- prior tracks in THIS target country
#
# ── CATEGORY D: DIFFUSION STATE (computed at observation_time) ───
# days_since_first_chart            INT        -- observation_time − first chart date
# num_countries_entered_so_far      INT        -- countries entered by observation_time
# num_continents_entered_so_far     INT        -- continents entered by observation_time
# best_rank_so_far                  DOUBLE     -- best rank in ANY country by observation_time
# rank_percentile_best              DOUBLE     -- best_rank / 200 (market-normalized)
# streams_log_sum_so_far            DOUBLE     -- log(total streams across all entered countries + 1)
# is_viral50_so_far                 INT        -- appeared on viral50 in any country by observation_time
# countries_entered_last_7d         INT        -- new countries entered in last 7 days (spread velocity)
# same_language_countries_entered   INT        -- entered countries sharing language with target
#
# ── CATEGORY E: TARGET COUNTRY ───────────────────────────────────
# target_country_population         DOUBLE     -- population (from aux data)
# target_country_continent          VARCHAR    -- one-hot encoded (6 continents)
# target_country_language_group     VARCHAR    -- one-hot encoded (top 8 languages)
# target_country_avg_daily_streams  DOUBLE     -- mean streams per entry
# target_country_new_entry_rate_30d DOUBLE     -- fraction NEW_ENTRY in last 30 days
# target_country_log_streams_recent DOUBLE     -- log(sum streams last 30 days + 1)
# target_country_unique_artists_30d INT        -- distinct artists in last 30 days
#
# ── CATEGORY F: DIFFUSION↔TARGET RELATIONSHIP ───────────────────
# same_language_flag                INT        -- first_chart_country language = target language
# same_continent_flag               INT        -- first_chart_country continent = target continent
# cultural_distance_imputed         DOUBLE     -- cultural distance (imputed if missing)
# cultural_distance_missing_flag    INT        -- 1 if imputed
# neighbor_already_entered_count    INT        -- of target's top-5 cultural neighbors, how many has the track already entered
# entered_same_continent_count      INT        -- of countries entered so far, how many share continent with target
#
# ── CATEGORY G: TEMPORAL ─────────────────────────────────────────
# observation_month                 INT        -- 1–12
# observation_quarter               INT        -- 1–4
# observation_day_of_week           INT        -- 0–6
# observation_year                  INT        -- 2017–2021
# is_december                       INT        -- 0 or 1
# ```
#
# ### Dataset Size Estimate
#
# With flexible observation points (~5 per track on average):
#
# ```
# ~118,000 unique tracks
# × ~5 observation points per track
# × ~60 candidate countries per observation (shrinks as song spreads)
# ≈ ~35M potential rows
#
# After filtering (valid track_id, audio features) and observation point sampling:
# ≈ ~5–10M rows
#
# Positive rate (did_enter_within_30d = 1): estimated ~4–8%
# ```
#
# This is large but DuckDB handles it. For model training, downsample negatives to ~5:1 ratio → ~2–3M training rows.

# %% [markdown]
# ## Train/Test Split Strategy
#
# ### Temporal Split (No Random Split)
#
# **Why:** Random splitting would leak future information. A song from 2021 in the training set teaches the model about artists/markets that a 2018 prediction couldn't know about.
#
# ```
# ┌──────────────────────────────────────────────────────────────┐
# │ 2017        2018        2019   │  2020      │  2021         │
# │ ◄──── TRAIN ─────────────────► │◄── VAL ──►│◄── TEST ────► │
# │                                │            │               │
# │  Build features, fit models    │  Tune      │  Final eval   │
# │                                │  hyperparams│  Report here  │
# └──────────────────────────────────────────────────────────────┘
# ```
#
# - **Train:** first chart date in 2017-01-01 to 2019-12-31
# - **Validation:** first chart date in 2020-01-01 to 2020-12-31
# - **Test:** first chart date in 2021-01-01 to 2021-12-31
#
# **Important:** Split by the track's **first chart date**, not by observation_time. All observation points of the same track must stay in the same split.
#
# ### Evaluation Metrics
#
# For the **top-5 ranker**, standard classification metrics (accuracy, F1) are misleading because we only care about the top of the ranking. Use:
#
# | Metric | What It Measures | Primary? |
# |--------|-----------------|----------|
# | **Precision@5** | Of the 5 predicted countries, how many actually entered within 30 days? | Yes |
# | **Recall@5** | Of all countries that entered within 30 days, how many were in our top 5? | Yes |
# | **NDCG@5** | Are the correct countries ranked higher? (Accounts for ordering) | Yes |
# | **Hit Rate@5** | For what fraction of songs did we get at least 1 correct country? | Yes |
# | **MAP@5** | Mean average precision across all songs | Secondary |
# | **RMSE (days)** | For correct predictions, how accurate is the day estimate? | For Model 2 |
#
# ### Practical Note on Evaluation
#
# Not every song *should* spread to 5 countries. The EDA shows 73% never leave their first market. For songs that spread to fewer than 5 countries within 30 days, Precision@5 is naturally capped. Consider also reporting:
# - **Precision@K where K = min(5, actual_spread_count)** — fairer for songs with limited spread
# - **"No spread" detection rate** — can the model identify songs that won't spread at all? (all probabilities below a threshold)

# %% [markdown]
# ## End-to-End Inference Pipeline
#
# This is how the trained system would be used in practice:
#
# ```
# Step 1: Song "X" by Artist "Y" has been charting for 5 days.
#         Currently in: Brazil (day 0), Argentina (day 3), Portugal (day 5).
#         → observation_time = day 5
#
# Step 2: Compute all features at this observation point:
#         - Track features: audio features, duration, explicit, 45 days since release
#         - Artist features: Y has 45 prior chart entries, charted in 12 countries,
#           best rank #3, 8 unique tracks, country_ratio = 1.5
#         - Diffusion state: 3 countries entered, 1 continent, best rank #15,
#           log(streams) = 11.8, 2 countries entered in last 7 days (spread velocity!)
#         - Temporal: March 2021, Wednesday, Q1
#
# Step 3: Create ~57 candidate rows (one per remaining eligible country):
#         - (X, day_5, Germany), (X, day_5, USA), (X, day_5, France), ...
#         - Each row gets the SAME track/artist/diffusion features
#         - Each row gets UNIQUE target country features + relationship features
#           e.g., (X, day_5, Spain) gets: same_language_flag=1 (Portuguese≈Spanish),
#                 same_continent_flag=0, neighbor_entered=2 (Argentina, Portugal are
#                 culturally close to Spain)
#
# Step 4: Model 1 scores each pair:
#         - P(X → Spain within 30d)   = 0.81
#         - P(X → Germany within 30d) = 0.72
#         - P(X → France within 30d)  = 0.68
#         - P(X → USA within 30d)     = 0.34
#         - P(X → Japan within 30d)   = 0.08
#         - ... (57 scores total)
#
# Step 5: Rank by probability, take top 5:
#         1. Spain     (P=0.81)
#         2. Germany   (P=0.72)
#         3. France    (P=0.68)
#         4. Italy     (P=0.55)
#         5. Colombia  (P=0.49)
#
# Step 6: Model 2 predicts days for top 5:
#         1. Spain     — ~2 days
#         2. Germany   — ~5 days
#         3. France    — ~8 days
#         4. Italy     — ~12 days
#         5. Colombia  — ~18 days
#
# Step 7: Final output:
#         "Song X (currently in Brazil, Argentina, Portugal) is most likely
#          to chart next in Spain (~2 days), Germany (~5 days), France (~8 days),
#          Italy (~12 days), and Colombia (~18 days)."
# ```
#
# ### The Same Model Works at Any Stage
#
# ```
# Day 0:  Song enters Brazil only          → "Next 5: Argentina, Portugal, Spain, Chile, Mexico"
# Day 5:  Now in Brazil+Argentina+Portugal  → "Next 5: Spain, Germany, France, Italy, Colombia"
# Day 12: Now in 8 countries                → "Next 5: Japan, South Korea, India, Turkey, Poland"
# ```
#
# The diffusion features automatically adapt — `num_countries_entered_so_far`, `countries_entered_last_7d`, `neighbor_already_entered_count` all change with each observation point.
#
# ### Model Candidates (in order of complexity)
#
# | Model | Type | Pros | Cons | Course Fit |
# |-------|------|------|------|------------|
# | **Logistic Regression** | Classifier | Interpretable, fast, baseline | Linear decision boundary | Core curriculum |
# | **Ridge/Lasso Regression** | Regressor (days) | Regularized, handles collinearity | Linear only | Core curriculum |
# | **ElasticNet** | Both | Best of Ridge + Lasso | Still linear | Core curriculum |
# | **Random Forest** | Both | Handles nonlinearity, feature importance | Slower, less interpretable | Extension |
# | **XGBoost / LightGBM** | Both | State-of-art for tabular data, handles imbalance | Black box, tuning needed | Extension |
#
# **Recommended approach:** Start with Logistic Regression + Ridge (course requirement), then compare with XGBoost to show improvement. This gives a clean narrative for the report: "baseline linear → improved with better features → further improved with nonlinear model."

# %% [markdown]
# ## Dataset v2 — Analysis-Ready Data
#
# ### Why a New Dataset Version?
#
# Dataset v1 was intentionally "merge-only, no cleaning" to allow EDA on raw data. Now that EDA is done, we need a clean dataset for feature engineering and modelling. Instead of applying filters in every query, we create **dataset v2** with these issues resolved at the data level.
#
# ### What v2 Drops
#
# | Filter | Rows Removed | Rationale |
# |--------|-------------|-----------|
# | `region = 'Global'` | ~1.7% (~445K rows) | Derived aggregate, not a real country. Would create fake "cross-border" events. |
# | Countries with incomplete coverage | Varies | Countries that joined late have truncated history, making fair comparison impossible. |
# | Rows where `track_id IS NULL` | ~1.16% (~304K rows) | No track identifier = can't build track-level features or join. |
#
# ### Which Countries to Drop?
#
# Countries with data starting significantly later than 2017-01-01:
#
# | Country | Data Start | Active Days (of 1826) | Action |
# |---------|------------|----------------------|--------|
# | South Korea | 2021-02-01 | 334 (18%) | **Drop** — less than 1 year of data |
# | Russia | 2020-07-14 | 536 (29%) | **Drop** — less than 1.5 years |
# | Ukraine | 2020-07-14 | 536 (29%) | **Drop** — less than 1.5 years |
# | India | 2019-02-26 | 1040 (57%) | **Borderline** — keep but flag. Has enough data for train+val+test if we're careful |
# | Saudi Arabia, Morocco, Egypt, UAE | Late 2018 | ~1100 (60%) | **Borderline** — keep but flag |
# | Vietnam, Israel, Romania, South Africa | 2018-03-14 | ~1388 (76%) | **Keep** — sufficient coverage |
# | All others | 2017-01-01 | 1826 (100%) | **Keep** |
#
# **Suggested threshold:** Drop countries with < 50% coverage (< 913 active days). This removes South Korea, Russia, Ukraine and keeps everything else. This is a decision to discuss with the team — we can adjust the threshold.
#
# ### v2 Storage
#
# ```
# datasets/v2/
#   └── full/
#       ├── year=2017/
#       ├── year=2018/
#       ├── year=2019/
#       ├── year=2020/
#       └── year=2021/
# ```
#
# Same Hive-partitioned Parquet structure as v1. A simple DuckDB query creates it:
#
# ```sql
# COPY (
#     SELECT *
#     FROM read_parquet('datasets/v1/full/year=*/**.parquet', hive_partitioning=true)
#     WHERE region != 'Global'
#       AND region NOT IN ('South Korea', 'Russia', 'Ukraine')  -- incomplete coverage
#       AND track_id IS NOT NULL
# ) TO 'datasets/v2/full/' (
#     FORMAT PARQUET, PARTITION_BY (year), COMPRESSION 'zstd'
# );
# ```
#
# ### What v2 Does NOT Do (left for feature engineering pipeline)
#
# - Type casting (still VARCHAR — cast at query time)
# - Deduplication of the 57 exact duplicates (negligible)
# - Outlier handling
# - Parsing `available_markets`
#
# These are better handled in the feature engineering SQL rather than baked into the dataset.
#
# ---
#
# ## Leakage Prevention Rules (Updated for 30-Day Ranker)
#
# All original rules still apply. Additional rules for the ranker setup:
#
# 1. **Temporal split is mandatory** — no random splitting. Train ≤2019, val 2020, test 2021.
# 2. **All observation points of the same track must be in the same split** — split by track's first chart date, not by observation_time. Otherwise a track could appear in train (day 0 observation) and test (day 15 observation).
# 3. **Artist features must use `date < observation_time`** — strictly before, not on the same day. Otherwise artist metrics include the song being predicted.
# 4. **Diffusion features use `date <= observation_time`** — the current state includes today, but NOT the future.
# 5. **Target country features use trailing windows ending at `observation_time - 1`** — the market state must be computed *before* the observation.
# 6. **No target country chart data for this specific track** — never use rank/streams of the track in the target country, even historical. The target country is what we're predicting.
# 7. **`popularity` remains excluded** — algorithmically updated by Spotify, reflects current performance.
# 8. **`available_markets_count` needs care** — may be updated retroactively. Flag for investigation.
# 9. **Downsampling negatives must happen after the temporal split** — downsample only within the training set. Validation and test sets keep their natural positive rate.
#
# ---
#
# ## Summary: What Changed From the Original Spec
#
# | Aspect | Original Spec | Revised (Top-5 Ranker) |
# |--------|--------------|----------------------|
# | **Output** | Binary (yes/no per country) + days | Top 5 ranked countries + days (30d horizon) |
# | **Prediction horizon** | Unbounded ("ever chart") | 30 days |
# | **Observation point** | First chart day only | Any point in song's life (day 1, 5, 7, ...) |
# | **Origin country** | Single origin, timezone/alphabet biased | No single origin; `first_chart_country` (best rank) for relationships only |
# | **Global region** | Not addressed | Dropped in dataset v2 |
# | **Incomplete countries** | Not addressed | Dropped in dataset v2 (South Korea, Russia, Ukraine) |
# | **`track_id`** | Unclear role | Explicitly an identifier only — dropped before training |
# | **Class imbalance** | Not addressed | Class weights + downsampling + ranking metrics |
# | **Audio features** | All raw values | Added binary versions for skewed features, dropped loudness |
# | **Artist features** | 5 features | 8 features (added country_ratio, avg_reach, target-specific) |
# | **Diffusion features** | 7 features (static at day 1) | 9 features (dynamic, change with each observation point) |
# | **Target country** | 5 features | 7 features (added avg_streams, artist diversity, new entry rate) |
# | **Cultural distance** | Raw join | Imputed with continent-pair median + missing flag |
# | **Temporal** | 2 features | 5 features (added year, quarter, december, friday) |
# | **Streams** | Raw values | Log-transformed everywhere |
# | **Train/test** | Not specified | Temporal split: train ≤2019, val 2020, test 2021 |
# | **Evaluation** | Accuracy/R² | Precision@5, NDCG@5, Hit Rate@5, RMSE(days) |
# | **Dataset** | v1 (raw, all regions) | v2 (clean: no Global, no incomplete countries, no null track_id) |
# | **Total features** | ~35 | ~47 (before one-hot encoding) |
